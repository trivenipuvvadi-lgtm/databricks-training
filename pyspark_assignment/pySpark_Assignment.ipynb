# %% [markdown]
# ### pyspark assignment_1

# %%
employee_data = [
    (101, "Alice", 25, "HR", 45000, "Chennai", "2022-01-15", 201),
    (102, "Bob", 30, "IT", 70000, "Bangalore", "2021-06-20", 202),
    (103, "Charlie", None, "IT", None, "Chennai", "2023-03-12", 202),
    (104, "David", 28, "Finance", 65000, "Mumbai", "2020-09-18", 203),
    (105, "Eva", 35, "HR", 80000, None, "2019-05-25", 201),
    (106, "Frank", 29, "Marketing", 55000, "Hyderabad", None, 204),
    (107, "Grace", 31, "Finance", None, "Pune", "2022-12-01", 203),
    (108, "Henry", 26, "IT", 60000, "Bangalore", "2024-01-10", None)
]

employee_columns = [
    "emp_id",
    "name",
    "age",
    "department",
    "salary",
    "city",
    "joining_date",
    "manager_id"
]

employee_df = spark.createDataFrame(employee_data, employee_columns)

employee_df.show()
employee_df.printSchema()
# Out:
# +------+-------+----+----------+------+---------+------------+----------+
# |emp_id|   name| age|department|salary|     city|joining_date|manager_id|
# +------+-------+----+----------+------+---------+------------+----------+
# |   101|  Alice|  25|        HR| 45000|  Chennai|  2022-01-15|       201|
# |   102|    Bob|  30|        IT| 70000|Bangalore|  2021-06-20|       202|
# |   103|Charlie|NULL|        IT|  NULL|  Chennai|  2023-03-12|       202|
# |   104|  David|  28|   Finance| 65000|   Mumbai|  2020-09-18|       203|
# |   105|    Eva|  35|        HR| 80000|     NULL|  2019-05-25|       201|
# |   106|  Frank|  29| Marketing| 55000|Hyderabad|        NULL|       204|
# |   107|  Grace|  31|   Finance|  NULL|     Pune|  2022-12-01|       203|
# |   108|  Henry|  26|        IT| 60000|Bangalore|  2024-01-10|      NULL|
# +------+-------+----+----------+------+---------+------------+----------+
#
# root
#  |-- emp_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- city: string (nullable = true)
#  |-- joining_date: string (nullable = true)
#  |-- manager_id: long (nullable = true)

# %%
department_data = [
    ("HR", "Chennai"),
    ("IT", "Bangalore"),
    ("Finance", "Mumbai"),
    ("Marketing", "Hyderabad"),
    ("Sales", "Delhi")
]

department_columns = [
    "dept_name",
    "location"
]

department_df = spark.createDataFrame(department_data, department_columns)

department_df.show()
department_df.printSchema()
# Out:
# +---------+---------+
# |dept_name| location|
# +---------+---------+
# |       HR|  Chennai|
# |       IT|Bangalore|
# |  Finance|   Mumbai|
# |Marketing|Hyderabad|
# |    Sales|    Delhi|
# +---------+---------+
#
# root
#  |-- dept_name: string (nullable = true)
#  |-- location: string (nullable = true)

# %%
manager_data = [
    (201, "Robert"),
    (202, "Jennifer"),
    (203, "Michael"),
    (204, "Sophia")
]

manager_columns = [
    "manager_id",
    "manager_name"
]

manager_df = spark.createDataFrame(manager_data, manager_columns)

manager_df.show()
manager_df.printSchema()
# Out:
# +----------+------------+
# |manager_id|manager_name|
# +----------+------------+
# |       201|      Robert|
# |       202|    Jennifer|
# |       203|     Michael|
# |       204|      Sophia|
# +----------+------------+
#
# root
#  |-- manager_id: long (nullable = true)
#  |-- manager_name: string (nullable = true)

# %%
new_employee_data = [
    (109, "Irene", 27, "HR", 52000, "Chennai", "2024-03-11", 201),
    (110, "Jack", 34, "Sales", 72000, "Delhi", "2021-11-20", 205)
]

new_employee_df = spark.createDataFrame(
    new_employee_data,
    employee_columns
)

new_employee_df.show()
# Out:
# +------+-----+---+----------+------+-------+------------+----------+
# |emp_id| name|age|department|salary|   city|joining_date|manager_id|
# +------+-----+---+----------+------+-------+------------+----------+
# |   109|Irene| 27|        HR| 52000|Chennai|  2024-03-11|       201|
# |   110| Jack| 34|     Sales| 72000|  Delhi|  2021-11-20|       205|
# +------+-----+---+----------+------+-------+------------+----------+

# %%
print("Employee DataFrame Schema")
employee_df.printSchema()

print("Department DataFrame Schema")
department_df.printSchema()

print("Manager DataFrame Schema")
manager_df.printSchema()
# Out:
# Employee DataFrame Schema
# root
#  |-- emp_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- city: string (nullable = true)
#  |-- joining_date: string (nullable = true)
#  |-- manager_id: long (nullable = true)
#
# Department DataFrame Schema
# root
#  |-- dept_name: string (nullable = true)
#  |-- location: string (nullable = true)
#
# Manager DataFrame Schema
# root
#  |-- manager_id: long (nullable = true)
#  |-- manager_name: string (nullable = true)

# %%
print("Employee DataFrame")
employee_df.display(5)

print("Department DataFrame")
department_df.display(5)

print("Manager DataFrame")
manager_df.display(5)
# Out:
# Employee DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>
# Department DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>HR</td><td>Chennai</td></tr><tr><td>IT</td><td>Bangalore</td></tr><tr><td>Finance</td><td>Mumbai</td></tr><tr><td>Marketing</td><td>Hyderabad</td></tr><tr><td>Sales</td><td>Delhi</td></tr></tbody></table></div>
# Manager DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>manager_id</th><th>manager_name</th></tr></thead><tbody><tr><td>201</td><td>Robert</td></tr><tr><td>202</td><td>Jennifer</td></tr><tr><td>203</td><td>Michael</td></tr><tr><td>204</td><td>Sophia</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col
employee_df.select(col("emp_id"),col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>45000</td></tr><tr><td>102</td><td>70000</td></tr><tr><td>103</td><td>null</td></tr><tr><td>104</td><td>65000</td></tr><tr><td>105</td><td>80000</td></tr><tr><td>106</td><td>55000</td></tr><tr><td>107</td><td>null</td></tr><tr><td>108</td><td>60000</td></tr></tbody></table></div>

# %%
employee_df.select(col("department")=="IT").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>(department = IT)</th></tr></thead><tbody><tr><td>false</td></tr><tr><td>true</td></tr><tr><td>true</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>true</td></tr></tbody></table></div>

# %%
employee_df.select(col("city").isin("Bangalore","Chennai")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>(city IN (Bangalore, Chennai))</th></tr></thead><tbody><tr><td>true</td></tr><tr><td>true</td></tr><tr><td>true</td></tr><tr><td>false</td></tr><tr><td>null</td></tr><tr><td>false</td></tr><tr><td>false</td></tr><tr><td>true</td></tr></tbody></table></div>

# %%
employee_df.withColumn("Annual_Salary",
    col("salary")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Annual_Salary</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>45000</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>70000</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>null</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>65000</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>80000</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>55000</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>null</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>60000</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import when

employee_df.withColumn("experience_bonus",
    when(col("salary") > 55000, 5000).otherwise(2000)
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>experience_bonus</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2000</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>5000</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2000</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>5000</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>5000</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>2000</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2000</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>5000</td></tr></tbody></table></div>

# %%
employee_df.withColumn("bonus", col("salary") * 0.20).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>bonus</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>9000.0</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>14000.0</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>null</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>13000.0</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>16000.0</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>11000.0</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>null</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>12000.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import upper
employee_df.select(upper(col("name"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>upper(name)</th></tr></thead><tbody><tr><td>ALICE</td></tr><tr><td>BOB</td></tr><tr><td>CHARLIE</td></tr><tr><td>DAVID</td></tr><tr><td>EVA</td></tr><tr><td>FRANK</td></tr><tr><td>GRACE</td></tr><tr><td>HENRY</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import lit
employee_df.withColumn( "Country",lit("India")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Country</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>India</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>India</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>India</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>India</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>India</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>India</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>India</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>India</td></tr></tbody></table></div>

# %%
employee_df.withColumnRenamed("department", "dept").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>dept</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.withColumnRenamed("salary", "monthly_salary").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>monthly_salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
(employee_df
    .withColumnRenamed("name", "emp_name")
    .withColumnRenamed("department", "dept")
    .display())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th><th>dept</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.filter(employee_df.salary>60000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr></tbody></table></div>

# %%
employee_df.filter(employee_df.age>30).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.filter(col("salary")>57000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.filter(col("salary").isNull()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.filter(col("department") == "HR").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr></tbody></table></div>

# %%
employee_df.filter(col("salary").isNotNull()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.filter(col("name").startswith("A")).show()
# Out:
# +------+-----+---+----------+------+-------+------------+----------+
# |emp_id| name|age|department|salary|   city|joining_date|manager_id|
# +------+-----+---+----------+------+-------+------------+----------+
# |   101|Alice| 25|        HR| 45000|Chennai|  2022-01-15|       201|
# +------+-----+---+----------+------+-------+------------+----------+

# %%
employee_df.sort(col("salary").asc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr></tbody></table></div>

# %%
employee_df.sort(col("salary").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.sort(col("age").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr></tbody></table></div>

# %%
employee_df.limit(3).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr></tbody></table></div>

# %%
employee_df.sort(col("department"), col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr></tbody></table></div>

# %%
employee_df.fillna(30000,subset=["salary"]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>30000</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>30000</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.fillna("unknown",subset=["city"]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>unknown</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
(employee_df.fillna(30000,subset=["salary"])
          .fillna("unknown",subset=["age"])
          .display())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>30000</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>30000</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.fillna("avg_age",subset=["age"]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.dropna("any").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.dropna(subset=["salary"]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.dropna("all").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *
df_crr = employee_df.withColumn('curr_date',current_date())
df_crr.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>curr_date</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2026-07-26</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2026-07-26</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2026-07-26</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2026-07-26</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2026-07-26</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>2026-07-26</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2026-07-26</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2026-07-26</td></tr></tbody></table></div>

# %%
df_crr.withColumn("joing date",date_add(col("curr_date"), 30)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>curr_date</th><th>joing date</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2026-07-26</td><td>2026-08-25</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2026-07-26</td><td>2026-08-25</td></tr></tbody></table></div>

# %%
df_crr.withColumn("joing date",date_add(col("curr_date"), 30)).withColumn("daysdiff",datediff(col("joing date"),col("curr_date"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>curr_date</th><th>joing date</th><th>daysdiff</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2026-07-26</td><td>2026-08-25</td><td>30</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "joining_date",
    to_date(col("joining_date"), "yyyy-MM-dd")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "Joining_Year",
    year(col("joining_date"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Joining_Year</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2022</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2021</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2023</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2020</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2019</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>null</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2022</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2024</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "Joining_month",
    year(col("joining_date"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Joining_month</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2022</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2021</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2023</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2020</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2019</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>null</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2022</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2024</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "Joining_day",
    year(col("joining_date"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Joining_day</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2022</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2021</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2023</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2020</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2019</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>null</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2022</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2024</td></tr></tbody></table></div>

# %%
employee_df.filter(
    year(col("joining_date")) == 2022
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "Current_Timestamp",
    current_timestamp()
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Current_Timestamp</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2026-07-26T06:17:39.969Z</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2026-07-26T06:17:39.969Z</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *

employee_df.withColumn(
    "Years_Worked",
    floor(datediff(current_date(), col("joining_date")) / 365)
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Years_Worked</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>4</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>5</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>3</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>5</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>7</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>null</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>3</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2</td></tr></tbody></table></div>

# %%
employee_df.filter(
    year(col("joining_date")) == year(current_date())
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ###joins

# %%
employee_df.join(department_df,employee_df.department == department_df.dept_name,"inner").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Marketing</td><td>Hyderabad</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>IT</td><td>Bangalore</td></tr></tbody></table></div>

# %%
employee_df.join(department_df,employee_df.department == department_df.dept_name,"left").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Marketing</td><td>Hyderabad</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>IT</td><td>Bangalore</td></tr></tbody></table></div>

# %%
employee_df.join(department_df,employee_df.department == department_df.dept_name,"right").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>IT</td><td>Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Marketing</td><td>Hyderabad</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Sales</td><td>Delhi</td></tr></tbody></table></div>

# %%
employee_df.join(department_df,employee_df.department == department_df.dept_name,"outer").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Marketing</td><td>Hyderabad</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>IT</td><td>Bangalore</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Sales</td><td>Delhi</td></tr></tbody></table></div>

# %%
employee_df.join(manager_df, "manager_id", "inner").select("name","manager_name").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>manager_name</th></tr></thead><tbody><tr><td>Alice</td><td>Robert</td></tr><tr><td>Bob</td><td>Jennifer</td></tr><tr><td>Charlie</td><td>Jennifer</td></tr><tr><td>David</td><td>Michael</td></tr><tr><td>Eva</td><td>Robert</td></tr><tr><td>Frank</td><td>Sophia</td></tr><tr><td>Grace</td><td>Michael</td></tr></tbody></table></div>

# %%
employee_df.join( department_df,employee_df.department == department_df.dept_name,"inner").filter(col("city") == col("location")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>HR</td><td>Chennai</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>IT</td><td>Bangalore</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Finance</td><td>Mumbai</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Marketing</td><td>Hyderabad</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>IT</td><td>Bangalore</td></tr></tbody></table></div>

# %%
department_df.join(employee_df,department_df.dept_name == employee_df.department,"left_anti").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>location</th></tr></thead><tbody><tr><td>Sales</td><td>Delhi</td></tr></tbody></table></div>

# %% [markdown]
# ###Union Operations

# %%
new_employee_data = [
    (109, "Irene", 27, "HR", 52000, "Chennai", "2024-03-11", 201),
    (110, "Jack", 34, "Sales", 72000, "Delhi", "2021-11-20", 205)
]

new_employee_df = spark.createDataFrame(
    new_employee_data,
    employee_columns
)

new_employee_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>109</td><td>Irene</td><td>27</td><td>HR</td><td>52000</td><td>Chennai</td><td>2024-03-11</td><td>201</td></tr><tr><td>110</td><td>Jack</td><td>34</td><td>Sales</td><td>72000</td><td>Delhi</td><td>2021-11-20</td><td>205</td></tr></tbody></table></div>

# %%
employee_df.union(new_employee_df).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>109</td><td>Irene</td><td>27</td><td>HR</td><td>52000</td><td>Chennai</td><td>2024-03-11</td><td>201</td></tr><tr><td>110</td><td>Jack</td><td>34</td><td>Sales</td><td>72000</td><td>Delhi</td><td>2021-11-20</td><td>205</td></tr></tbody></table></div>

# %%
employee_df.union(new_employee_df).count()
# Out:
# 10

# %%
(employee_df.union(new_employee_df)
 .dropDuplicates()
 .display())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>109</td><td>Irene</td><td>27</td><td>HR</td><td>52000</td><td>Chennai</td><td>2024-03-11</td><td>201</td></tr><tr><td>110</td><td>Jack</td><td>34</td><td>Sales</td><td>72000</td><td>Delhi</td><td>2021-11-20</td><td>205</td></tr></tbody></table></div>

# %%
employee_df.unionByName(new_employee_df).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr><tr><td>109</td><td>Irene</td><td>27</td><td>HR</td><td>52000</td><td>Chennai</td><td>2024-03-11</td><td>201</td></tr><tr><td>110</td><td>Jack</td><td>34</td><td>Sales</td><td>72000</td><td>Delhi</td><td>2021-11-20</td><td>205</td></tr></tbody></table></div>

# %% [markdown]
# ###Other Transformations

# %%
employee_df.select("department").distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th></tr></thead><tbody><tr><td>HR</td></tr><tr><td>IT</td></tr><tr><td>Finance</td></tr><tr><td>Marketing</td></tr></tbody></table></div>

# %%
employee_df.groupBy("department") \
           .count() \
           .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count</th></tr></thead><tbody><tr><td>HR</td><td>2</td></tr><tr><td>IT</td><td>3</td></tr><tr><td>Finance</td><td>2</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import avg
employee_df.groupBy("department") \
    .agg(avg("salary").alias("Average_Salary")) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Average_Salary</th></tr></thead><tbody><tr><td>HR</td><td>62500.0</td></tr><tr><td>IT</td><td>65000.0</td></tr><tr><td>Finance</td><td>65000.0</td></tr><tr><td>Marketing</td><td>55000.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import max
employee_df.groupBy("department") \
    .agg(max("salary").alias("Maximum_Salary")) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Maximum_Salary</th></tr></thead><tbody><tr><td>HR</td><td>80000</td></tr><tr><td>IT</td><td>70000</td></tr><tr><td>Finance</td><td>65000</td></tr><tr><td>Marketing</td><td>55000</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import min

employee_df.groupBy("department") \
    .agg(min("salary").alias("Minimum_Salary")) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Minimum_Salary</th></tr></thead><tbody><tr><td>HR</td><td>45000</td></tr><tr><td>IT</td><td>60000</td></tr><tr><td>Finance</td><td>65000</td></tr><tr><td>Marketing</td><td>55000</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import sum

employee_df.groupBy("department") \
    .agg(sum("salary").alias("Total_Salary")) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Total_Salary</th></tr></thead><tbody><tr><td>HR</td><td>125000</td></tr><tr><td>IT</td><td>130000</td></tr><tr><td>Finance</td><td>65000</td></tr><tr><td>Marketing</td><td>55000</td></tr></tbody></table></div>

# %%
employee_df.groupBy("city") \
    .count() \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td>Chennai</td><td>2</td></tr><tr><td>Bangalore</td><td>2</td></tr><tr><td>Mumbai</td><td>1</td></tr><tr><td>null</td><td>1</td></tr><tr><td>Hyderabad</td><td>1</td></tr><tr><td>Pune</td><td>1</td></tr></tbody></table></div>

# %%
employee_df.select("city") \
    .distinct() \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th></tr></thead><tbody><tr><td>Chennai</td></tr><tr><td>Bangalore</td></tr><tr><td>Mumbai</td></tr><tr><td>null</td></tr><tr><td>Hyderabad</td></tr><tr><td>Pune</td></tr></tbody></table></div>

# %%
employee_df.dropDuplicates().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.drop("manager_id").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import lower
employee_df.withColumn(
    "Lower_Name",
    lower(col("name"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Lower_Name</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>alice</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>bob</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>charlie</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>david</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>eva</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>frank</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>grace</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>henry</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import length

employee_df.withColumn(
    "Name_Length",
    length(col("name"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Name_Length</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>5</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>3</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>7</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>5</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>3</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>5</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>5</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>5</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import substring
employee_df.withColumn( "First_3_Letters", substring(col("name"), 1, 3)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>First_3_Letters</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>Ali</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>Bob</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>Cha</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>Dav</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>Eva</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Fra</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Gra</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>Hen</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import concat, lit
employee_df.withColumn("Name_City", concat(col("name"), lit(" - "), col("city"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Name_City</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>Alice - Chennai</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>Bob - Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>Charlie - Chennai</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>David - Mumbai</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>null</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Frank - Hyderabad</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Grace - Pune</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>Henry - Bangalore</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import regexp_replace
employee_df.withColumn( "Updated_Name", regexp_replace(col("name"), "a", "@")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Updated_Name</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>Alice</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>Bob</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>Ch@rlie</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>D@vid</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>Ev@</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>Fr@nk</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>Gr@ce</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>Henry</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import sum
employee_df.select(sum("salary").alias("Total_Salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Salary</th></tr></thead><tbody><tr><td>375000</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import avg
employee_df.select(sum("salary").alias("avg_Salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_Salary</th></tr></thead><tbody><tr><td>375000</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import min

min_salary = employee_df.select(min("salary")).collect()[0][0]

employee_df.filter(
    col("salary") == min_salary
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr></tbody></table></div>

# %%
employee_df.filter(col("salary") > 50000).count()
# Out:
# 5

# %%
from pyspark.sql.functions import avg, col
dept_avg = employee_df.groupBy("department") \
    .agg(avg("salary").alias("avg_salary"))
employee_df.join(
    dept_avg,
    "department"
).filter(
    col("salary") > col("avg_salary")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>emp_id</th><th>name</th><th>age</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>avg_salary</th></tr></thead><tbody><tr><td>IT</td><td>102</td><td>Bob</td><td>30</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>65000.0</td></tr><tr><td>HR</td><td>105</td><td>Eva</td><td>35</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>62500.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank

window = Window.orderBy(col("salary").desc())

employee_df.withColumn(
    "Rank",
    dense_rank().over(window)
).filter(
    col("Rank") == 2
).display()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Rank</th></tr></thead><tbody><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>2</td></tr></tbody></table></div>

# %%
employee_df.groupBy("city") \
    .count() \
    .filter(col("count") > 1) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count</th></tr></thead><tbody><tr><td>Chennai</td><td>2</td></tr><tr><td>Bangalore</td><td>2</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import add_months, current_date

employee_df.filter(
    col("joining_date") >= add_months(current_date(), -24)
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody></tbody></table></div>

# %%
employee_df.fillna(
    {"manager_id": 999}
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>999</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import when

employee_df.withColumn(
    "Salary_Grade",
    when(col("salary") >= 80000, "A")
    .when(col("salary") >= 60000, "B")
    .when(col("salary") >= 40000, "C")
    .otherwise("D")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Salary_Grade</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>C</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>B</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>D</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>B</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>A</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>C</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>D</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>B</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import concat, lit

employee_df.withColumn(
    "Employee_Code",
    concat(lit("EMP"), col("emp_id"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Employee_Code</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>EMP101</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>EMP102</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>EMP103</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>EMP104</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>EMP105</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>EMP106</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>EMP107</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>EMP108</td></tr></tbody></table></div>

# %%
employee_df.filter(
    col("name").endswith("e")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr></tbody></table></div>

# %%
employee_df.orderBy(
    col("joining_date")
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import datediff, current_date, col

employee_df.withColumn(
    "Years_Worked",
    (datediff(current_date(), col("joining_date")) / 365)
).filter(
    col("Years_Worked") > 3
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Years_Worked</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>4.528767123287671</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>5.101369863013699</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>3.3753424657534246</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>5.854794520547945</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>7.175342465753425</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>3.652054794520548</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank

window_spec = Window.partitionBy("department").orderBy(col("salary").desc())

employee_df.withColumn(
    "Rank",
    rank().over(window_spec)
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Rank</th></tr></thead><tbody><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>1</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>1</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>1</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>3</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank

window_spec = Window.partitionBy("department").orderBy(col("salary").desc())

employee_df.withColumn(
    "Rank",
    dense_rank().over(window_spec)
).filter(
    col("Rank") <= 2
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Rank</th></tr></thead><tbody><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>1</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>2</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>1</td></tr><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>2</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>1</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>2</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import avg

employee_df.groupBy("department") \
    .agg(avg("salary").alias("Average_Salary")) \
    .filter(col("Average_Salary") > 60000) \
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Average_Salary</th></tr></thead><tbody><tr><td>HR</td><td>62500.0</td></tr><tr><td>IT</td><td>65000.0</td></tr><tr><td>Finance</td><td>65000.0</td></tr></tbody></table></div>

# %%
employee_df.filter(
    col("manager_id").isNull()
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.join(
    manager_df,
    "manager_id",
    "left"
).join(
    department_df,
    employee_df.department == department_df.dept_name,
    "left"
).select(
    "emp_id",
    "name",
    "department",
    "manager_name",
    "location"
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>manager_name</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>HR</td><td>Robert</td><td>Chennai</td></tr><tr><td>102</td><td>Bob</td><td>IT</td><td>Jennifer</td><td>Bangalore</td></tr><tr><td>103</td><td>Charlie</td><td>IT</td><td>Jennifer</td><td>Bangalore</td></tr><tr><td>104</td><td>David</td><td>Finance</td><td>Michael</td><td>Mumbai</td></tr><tr><td>105</td><td>Eva</td><td>HR</td><td>Robert</td><td>Chennai</td></tr><tr><td>106</td><td>Frank</td><td>Marketing</td><td>Sophia</td><td>Hyderabad</td></tr><tr><td>107</td><td>Grace</td><td>Finance</td><td>Michael</td><td>Mumbai</td></tr><tr><td>108</td><td>Henry</td><td>IT</td><td>null</td><td>Bangalore</td></tr></tbody></table></div>

# %%
employee_df.filter(
    col("age").isNull() |
    col("salary").isNull() |
    col("city").isNull() |
    col("joining_date").isNull() |
    col("manager_id").isNull()
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import avg, when

dept_avg = employee_df.groupBy("department") \
    .agg(avg("salary").alias("Avg_Salary"))

employee_df.join(
    dept_avg,
    "department"
).withColumn(
    "salary",
    when(col("salary").isNull(), col("Avg_Salary"))
    .otherwise(col("salary"))
).drop("Avg_Salary").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>emp_id</th><th>name</th><th>age</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>HR</td><td>101</td><td>Alice</td><td>25</td><td>45000.0</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>IT</td><td>102</td><td>Bob</td><td>30</td><td>70000.0</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>IT</td><td>103</td><td>Charlie</td><td>null</td><td>65000.0</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>Finance</td><td>104</td><td>David</td><td>28</td><td>65000.0</td><td>Mumbai</td><td>2020-09-18</td><td>203</td></tr><tr><td>HR</td><td>105</td><td>Eva</td><td>35</td><td>80000.0</td><td>null</td><td>2019-05-25</td><td>201</td></tr><tr><td>Marketing</td><td>106</td><td>Frank</td><td>29</td><td>55000.0</td><td>Hyderabad</td><td>null</td><td>204</td></tr><tr><td>Finance</td><td>107</td><td>Grace</td><td>31</td><td>65000.0</td><td>Pune</td><td>2022-12-01</td><td>203</td></tr><tr><td>IT</td><td>108</td><td>Henry</td><td>26</td><td>60000.0</td><td>Bangalore</td><td>2024-01-10</td><td>null</td></tr></tbody></table></div>

# %%
employee_df.withColumn(
    "Monthly_Tax",
    col("salary") * 0.10
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th><th>Monthly_Tax</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td><td>4500.0</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td><td>7000.0</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td><td>null</td></tr><tr><td>104</td><td>David</td><td>28</td><td>Finance</td><td>65000</td><td>Mumbai</td><td>2020-09-18</td><td>203</td><td>6500.0</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td><td>8000.0</td></tr><tr><td>106</td><td>Frank</td><td>29</td><td>Marketing</td><td>55000</td><td>Hyderabad</td><td>null</td><td>204</td><td>5500.0</td></tr><tr><td>107</td><td>Grace</td><td>31</td><td>Finance</td><td>null</td><td>Pune</td><td>2022-12-01</td><td>203</td><td>null</td></tr><tr><td>108</td><td>Henry</td><td>26</td><td>IT</td><td>60000</td><td>Bangalore</td><td>2024-01-10</td><td>null</td><td>6000.0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import dayofweek

employee_df.filter(
    dayofweek(col("joining_date")).isin(1, 7)
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>department</th><th>salary</th><th>city</th><th>joining_date</th><th>manager_id</th></tr></thead><tbody><tr><td>101</td><td>Alice</td><td>25</td><td>HR</td><td>45000</td><td>Chennai</td><td>2022-01-15</td><td>201</td></tr><tr><td>102</td><td>Bob</td><td>30</td><td>IT</td><td>70000</td><td>Bangalore</td><td>2021-06-20</td><td>202</td></tr><tr><td>103</td><td>Charlie</td><td>null</td><td>IT</td><td>null</td><td>Chennai</td><td>2023-03-12</td><td>202</td></tr><tr><td>105</td><td>Eva</td><td>35</td><td>HR</td><td>80000</td><td>null</td><td>2019-05-25</td><td>201</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *

employee_df.join(
    manager_df,
    "manager_id",
    "left"
).join(
    department_df,
    employee_df.department == department_df.dept_name,
    "left"
).withColumn(
    "Bonus",
    col("salary") * 0.10
).withColumn(
    "Annual_Salary",
    col("salary") * 12
).withColumn(
    "Years_Worked",
    floor(datediff(current_date(), col("joining_date")) / 365)
).withColumn(
    "Salary_Grade",
    when(col("salary") >= 80000, "A")
    .when(col("salary") >= 60000, "B")
    .when(col("salary") >= 40000, "C")
    .otherwise("D")
).select(
    "name",
    "department",
    "manager_name",
    "location",
    "salary",
    "Bonus",
    "Annual_Salary",
    "Years_Worked",
    "Salary_Grade"
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>department</th><th>manager_name</th><th>location</th><th>salary</th><th>Bonus</th><th>Annual_Salary</th><th>Years_Worked</th><th>Salary_Grade</th></tr></thead><tbody><tr><td>Alice</td><td>HR</td><td>Robert</td><td>Chennai</td><td>45000</td><td>4500.0</td><td>540000</td><td>4</td><td>C</td></tr><tr><td>Bob</td><td>IT</td><td>Jennifer</td><td>Bangalore</td><td>70000</td><td>7000.0</td><td>840000</td><td>5</td><td>B</td></tr><tr><td>Charlie</td><td>IT</td><td>Jennifer</td><td>Bangalore</td><td>null</td><td>null</td><td>null</td><td>3</td><td>D</td></tr><tr><td>David</td><td>Finance</td><td>Michael</td><td>Mumbai</td><td>65000</td><td>6500.0</td><td>780000</td><td>5</td><td>B</td></tr><tr><td>Eva</td><td>HR</td><td>Robert</td><td>Chennai</td><td>80000</td><td>8000.0</td><td>960000</td><td>7</td><td>A</td></tr><tr><td>Frank</td><td>Marketing</td><td>Sophia</td><td>Hyderabad</td><td>55000</td><td>5500.0</td><td>660000</td><td>null</td><td>C</td></tr><tr><td>Grace</td><td>Finance</td><td>Michael</td><td>Mumbai</td><td>null</td><td>null</td><td>null</td><td>3</td><td>D</td></tr><tr><td>Henry</td><td>IT</td><td>null</td><td>Bangalore</td><td>60000</td><td>6000.0</td><td>720000</td><td>2</td><td>B</td></tr></tbody></table></div>
